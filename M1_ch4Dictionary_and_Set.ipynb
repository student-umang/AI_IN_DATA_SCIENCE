# %% [markdown]
# ## **DICTIONARY AND SET**

# %% [markdown]
# **Dictionary**

# %% [markdown]
# Write a program to print a dictionary in python

# %%
#WAP to print a dictionary
std = {
    "name" : "robin",
    "age" : 20,
    "marks" :[20,30,25.20],
    "status" : True,
}
print(std)
# Out:
# {'name': 'robin', 'age': 20, 'marks': [20, 30, 25.2], 'status': True}

# %% [markdown]
# Write a program to print a dictionary with an empty key value

# %%
inf = {
    "name" : "robin",
    "age" : 20,
    "marks" :[20,30,25.20],
    "status" : True,
    "empty" : " ",
}
print(inf)
# Out:
# {'name': 'robin', 'age': 20, 'marks': [20, 30, 25.2], 'status': True, 'empty': ' '}

# %% [markdown]
# Write a program to print same key but diffrent value in a dictionary

# %%
#WAP to print same key of a dictionary
std = {
"name" : "kanishka",
"name" : "umang",
}
print(std)
# Out:
# {'name': 'umang'}

# %% [markdown]
#  Write a program to print the same value but diffrent key in a dictionary

# %%
#WAP to print same multiple values
std = {
    "name1" : "umii",
    "name2" : "umii",
}
print(std)
# Out:
# {'name1': 'umii', 'name2': 'umii'}

# %% [markdown]
# Write a program to change the   value

# %%
#WAP to change the value
std ["name"] = "farman"
print(std)
# Out:
# {'name': 'farman', 'age': 20, 'marks': [20, 30, 25.2], 'status': True}

# %% [markdown]
# Write a program to add new key value pair in a dictionary

# %%
#WAP to add new key value pair in a dictionary
inf["roll no."] = 15
print(inf)
# Out:
# {'name': 'farman', 'age': 20, 'marks': [20, 30, 25.2], 'status': True, 'empty': ' ', 'roll no.': 15}

# %% [markdown]
#  Write a program to print the nested dictionary in python

# %%
#nested dictionary
std = {
    "name" : "rahul",
    "age" : 20,
    "marks" : {                     #used to print dictionary in the dictionary
        "p" : 30,
        "m" : 40,
        "ch" : 50,
    }
}
print(std)
# Out:
# {'name': 'rahul', 'age': 20, 'marks': {'p': 30, 'm': 40, 'ch': 50}}

# %% [markdown]
# **Dictionary Method**

# %% [markdown]
# Write a program print tuple in a dictionary

# %%
#WAP to print tuple in a dictionary
std = {
    "name" : "rahul",
    "age" : 20,
    "tup" : {1,2,3},
}
print(std)
# Out:
# {'name': 'rahul', 'age': 20, 'tup': {1, 2, 3}}

# %% [markdown]
# Write a program to create a dictionary containing student name and age , display all the keys

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.keys()
# Out:
# dict_keys(['name', 'age'])

# %% [markdown]
# Write a program to create a dictionary containing student name and age , display all the values

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.values()
# Out:
# dict_values(['rahul', 20])

# %% [markdown]
# Write a Python program to create a dictionary containing student name and age, and retrieve the value of the "name" key using the items() method

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.items()
# Out:
# dict_items([('name', 'rahul'), ('age', 20)])

# %% [markdown]
# Write a Python program to create a dictionary containing student name and age,remove the dictionary  using the clear() method.

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.clear()

# %% [markdown]
# Write a Python program to create a dictionary containing student name and age, and update the student's name using the get() method.

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.get("name")
# Out:
# 'rahul'

# %% [markdown]
# Write a Python program to create a dictionary containing student name and age, and update the student's name using the update() method.

# %%
std = {
    "name" : "rahul",
    "age" : 20,
}
std.update({"name" : "rahul"})

# %% [markdown]
# ##SET

# %% [markdown]
# Write a program to length of the set

# %%
#WAP to print length of set
set = {1,2,3,4,5,4,5,6,5,1,2,3}
print(len(set))
# Out:
# 6

# %% [markdown]
# Write a program to print the union of two set

# %%
#WAP for union
a = {1,2,3,4,5,6}
b = { 3,4,5,6,7,8,9}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# Write a program to print the intersection of two set

# %%
#WAP to for intersection
a = {1,2,3,4,5,6}
b = { 3,4,5,6,7,8,9}
a.intersection(b)
# Out:
# {3, 4, 5, 6}

# %% [markdown]
# Write a program to find the diffrence between two set

# %%
#WAP for difference
a = {1,2,3,4,5,6}
b = { 3,4,5,6,7,8,9}
a - b
b - a
# Out:
# {7, 8, 9}
