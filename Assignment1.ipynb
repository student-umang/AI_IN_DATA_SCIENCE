# %% [markdown]
# ## CONDITIONAL STATEMENT QUESTIONS:

# %%
#WAP to find the larest no. from 3 input
a = 10
b = 60
c = 30
if a > b and a > c:
  print("A is greater")
elif b > a and b > c:
  print("b is greater")
else:
  print("c is greater")

# %%
#To print the bill
unit = int(input('enter the unit:'))
if unit > 0 and unit <= 100:
  print(unit*5)
if unit > 101 and unit <= 200:
  print(unit * 10)
elif unit > 201:
  print(unit * 15)

# %%
# Write a program to check whether a year is leap year or not
year = int(input("enter the year:"))
if year %4 == 0:
  if(year % 400 == 0 or year % 100 != 0):
    print(year,"is leap year")
  else:
    print(year, "is not a leap year")

# %%
# Write a program to check whether a character is an upper case letter, lower case letter,digit orspecial character


ch = input("Enter a single character: ")

if len(ch) != 1:
    print("Please enter only one character.")
elif 'A' <= ch <= 'Z':
    print("The character is an uppercase letter.")
elif 'a' <= ch <= 'z':
    print("The character is a lowercase letter.")
elif '0' <= ch <= '9':
    print("The character is a digit.")
else:
    print("The character is a special character.")
# Out:
# Enter a single character: h
# The character is a lowercase letter.

# %%
#Write a program to determine whether triangle is an equilateral,isosceles and scalene


a = float(input("Enter the first side: "))
b = float(input("Enter the second side: "))
c = float(input("Enter the third side: "))

# Check if the sides can form a triangle
if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        print("The triangle is Equilateral.")
    elif a == b or b == c or a == c:
        print("The triangle is Isosceles.")
    else:
        print("The triangle is Scalene.")
else:
    print("The given sides do not form a valid triangle.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_946/757937066.py in <cell line: 0>()
#       2
#       3
# ----> 4 a = float(input("Enter the first side: "))
#       5 b = float(input("Enter the second side: "))
#       6 c = float(input("Enter the third side: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
#Write a program to create a simple calculator using if-elif-else


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("\nChoose an operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")

choice = input("Enter your choice (+, -, *, /): ")

if choice == "+":
    print("Result =", num1 + num2)
elif choice == "-":
    print("Result =", num1 - num2)
elif choice == "*":
    print("Result =", num1 * num2)
elif choice == "/":
    if num2 != 0:
        print("Result =", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")
else:
    print("Invalid choice!")

# %%
#Write a program to calculate income tax according to  salary ranges


salary = float(input("Enter your annual salary: "))

if salary <= 250000:
    tax = 0
elif salary <= 500000:
    tax = salary * 0.05
elif salary <= 1000000:
    tax = salary * 0.20
else:
    tax = salary * 0.30

print("Annual Salary = ₹", salary)
print("Income Tax = ₹", tax)

# %%
#Write a program  to check login authentication used in username and password conditions


username = input("Enter username: ")
password = input("Enter password: ")

# Predefined username and password
correct_username = "admin"
correct_password = "12345"

if username == correct_username and password == correct_password:
    print("Login Successful!")
elif username != correct_username:
    print("Invalid Username!")
elif password != correct_password:
    print("Invalid Password!")
else:
    print("Login Failed!")

# %%
#write a program to determine whether a point lies in first quadrant, second quadrant, third quadrant, fourth quadrant, on axis or at origin

x = float(input("Enter x-coordinate: "))
y = float(input("Enter y-coordinate: "))

if x > 0 and y > 0:
    print("The point lies in the First Quadrant.")
elif x < 0 and y > 0:
    print("The point lies in the Second Quadrant.")
elif x < 0 and y < 0:
    print("The point lies in the Third Quadrant.")
elif x > 0 and y < 0:
    print("The point lies in the Fourth Quadrant.")
elif x == 0 and y == 0:
    print("The point is at the Origin.")
elif x == 0:
    print("The point lies on the Y-axis.")
elif y == 0:
    print("The point lies on the X-axis.")

# %%
#write a program to assign grades based on marks and display distinction for high scores


marks = float(input("Enter your marks (0-100): "))

if marks < 0 or marks > 100:
    print("Invalid marks! Please enter marks between 0 and 100.")
elif marks >= 85:
    print("Grade: A")
    print("Result: Distinction")
elif marks >= 70:
    print("Grade: B")
elif marks >= 55:
    print("Grade: C")
elif marks >= 40:
    print("Grade: D")
else:
    print("Grade: F")
    print("Result: Fail")

# %% [markdown]
# ##QUESTIONS ON DICTIONARY AND SET

# %%
#Write a program to create a dictionary from two list : one of keys and one of values


keys = input("Enter the keys separated by spaces: ").split()
values = input("Enter the values separated by spaces: ").split()

# Check if both lists have the same length
if len(keys) == len(values):
    my_dict = dict(zip(keys, values))
    print("Dictionary:", my_dict)
else:
    print("Error! The number of keys and values must be the same.")

# %%
# Program to merge two dictionaries into one# Program to merge two dictionaries

dict1 = {}

n1 = int(input("Enter the number of items in the first dictionary: "))
print("Enter key-value pairs for the first dictionary:")
for i in range(n1):
    key = input("Key: ")
    value = input("Value: ")
    dict1[key] = value

dict2 = {}

n2 = int(input("\nEnter the number of items in the second dictionary: "))
print("Enter key-value pairs for the second dictionary:")
for i in range(n2):
    key = input("Key: ")
    value = input("Value: ")
    dict2[key] = value

# Merge dictionaries
merged_dict = {**dict1, **dict2}

print("\nMerged Dictionary:")
print(merged_dict)

dict1 = {}

n1 = int(input("Enter the number of items in the first dictionary: "))
print("Enter key-value pairs for the first dictionary:")
for i in range(n1):
    key = input("Key: ")
    value = input("Value: ")
    dict1[key] = value

dict2 = {}

n2 = int(input("\nEnter the number of items in the second dictionary: "))
print("Enter key-value pairs for the second dictionary:")
for i in range(n2):
    key = input("Key: ")
    value = input("Value: ")
    dict2[key] = value

# Merge dictionaries
merged_dict = {**dict1, **dict2}

print("\nMerged Dictionary:")
print(merged_dict)

# %%
#write a program to sort a dictionary by its value


my_dict = {}

n = int(input("Enter the number of items: "))

for i in range(n):
    key = input("Enter key: ")
    value = int(input("Enter value: "))
    my_dict[key] = value

# Sort dictionary by values
sorted_dict = dict(sorted(my_dict.items(), key=lambda item: item[1]))

print("Dictionary sorted by values:")
print(sorted_dict)

# %%
#write a program to sort a dictionary by its value

my_dict = {
    "Apple": 50,
    "Banana": 20,
    "Mango": 40,
    "Orange": 30
}

# Sort in ascending order of values
sorted_items = sorted(my_dict.items(), key=lambda x: x[1])

print("Dictionary sorted by values:")
for key, value in sorted_items:
    print(key, ":", value)

# %%
#write a program to check whether two lists have a least one common element using sets

list1 = list(map(int, input("Enter elements of first list separated by spaces: ").split()))
list2 = list(map(int, input("Enter elements of second list separated by spaces: ").split()))

# Convert lists to sets and find common elements
common = set(list1) & set(list2)

if common:
    print("The two lists have common element(s):", common)
else:
    print("The two lists do not have any common elements.")

# %% [markdown]
# ##QUESTIONS ON LISTS AND TUPLE

# %%
#write a program to find the largest and smallest elements in a list

numbers = list(map(int, input("Enter the elements of the list separated by spaces: ").split()))

largest = max(numbers)
smallest = min(numbers)

print("Largest element:", largest)
print("Smallest element:", smallest)

# %%
#write a program to remove duplicate elements from a lsit

numbers = list(map(int, input("Enter the list elements separated by spaces: ").split()))

unique_list = list(set(numbers))

print("List after removing duplicates:")
print(unique_list)

# %%
#write a program to reverse a list without using built - in reverse functions

numbers = list(map(int, input("Enter the list elements separated by spaces: ").split()))

reversed_list = []

# Traverse the list from the last element to the first
for i in range(len(numbers) - 1, -1, -1):
    reversed_list.append(numbers[i])

print("Reversed List:")
print(reversed_list)

# %%
#write a program to count even and odd numbers in a list

numbers = list(map(int, input("Enter the list elements separated by spaces: ").split()))

even_count = 0
odd_count = 0

for num in numbers:
    if num % 2 == 0:
        even_count += 1
    else:
        odd_count += 1

print("Number of even elements:", even_count)
print("Number of odd elements:", odd_count)

# %%
#write a program to merge two lists and sort the final list

list1 = list(map(int, input("Enter elements of first list separated by spaces: ").split()))
list2 = list(map(int, input("Enter elements of second list separated by spaces: ").split()))

# Merge the lists
merged_list = list1 + list2

# Sort the merged list
merged_list.sort()

print("Merged and Sorted List:")
print(merged_list)

# %%
#write a program to find the second largest element in a list

numbers = list(map(int, input("Enter the list elements separated by spaces: ").split()))

# Remove duplicate elements and sort the list
unique_numbers = list(set(numbers))
unique_numbers.sort()

if len(unique_numbers) < 2:
    print("There is no second largest element.")
else:
    print("Second largest element:", unique_numbers[-2])

# %%
#write a program to check whether an element exists in a tuple

numbers = tuple(map(int, input("Enter tuple elements separated by spaces: ").split()))

element = int(input("Enter the element to search: "))

if element in numbers:
    print("Element exists in the tuple.")
else:
    print("Element does not exist in the tuple.")

# %%
#write a program to count the occurrence of an element  in a tuple

numbers = tuple(map(int, input("Enter tuple elements separated by spaces: ").split()))

element = int(input("Enter the element to count: "))

count = numbers.count(element)

print("The element", element, "occurs", count, "time(s) in the tuple.")

# %%
#write a program to sort a list of tuples based on tuple values

tuples_list = []

n = int(input("Enter the number of tuples: "))

for i in range(n):
    first = input("Enter first value: ")
    second = int(input("Enter second value: "))
    tuples_list.append((first, second))

# Sort the list based on the second value of each tuple
sorted_list = sorted(tuples_list, key=lambda x: x[1])

print("Sorted list of tuples:")
print(sorted_list)

# %%
# write a program to convert a tuple into list and a list into tuples

# Program to convert a tuple into a list and a list into a tuple

# Tuple to List
my_tuple = (10, 20, 30, 40, 50)
print("Original Tuple:", my_tuple)

my_list = list(my_tuple)
print("Converted List:", my_list)

# List to Tuple
my_list2 = [60, 70, 80, 90, 100]
print("\nOriginal List:", my_list2)

my_tuple2 = tuple(my_list2)
print("Converted Tuple:", my_tuple2)
# Out:
# Original Tuple: (10, 20, 30, 40, 50)
# Converted List: [10, 20, 30, 40, 50]
#
# Original List: [60, 70, 80, 90, 100]
# Converted Tuple: (60, 70, 80, 90, 100)
