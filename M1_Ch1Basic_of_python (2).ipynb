# %% [markdown]
# #**Basic** **of** **python**

# %% [markdown]
# 1) Write a program to print  basic string

# %%
#WAP to print  basic string
print(''' ("farman's house")''')  #print name
# Out:
#  ("farman's house")

# %% [markdown]
# sum code

# %% [markdown]
# 2. Write a program to print sum of two variable

# %%
# sum of two number
n1=5                     #assign  n1
n2=5                     #assign n2
sum=n1 +n2
print(sum)
# Out:
# 10

# %%
# WAP to divide using //
print(5//2)             #print output in integer
# Out:
# 2

# %% [markdown]
# **## opeartors**

# %% [markdown]
# 3.Write the program using operator
# (Relational operator,
# Logical operator)

# %%
# WAP  to find the greater number(relational operater)

a=5
b=print(a<b)               #relational operator (<)
# Out:
# True

# %%
# true ir false(relational operator)
a=5
b=5
print(a==b)
# Out:
# True

# %%
# logical operator
print(True and False)         #using and operator
print(True and True)
print(False and False)
# Out:
# False
# True
# False

# %%
#logical operator
print(True or False)               #using or operator
print(True or True)
print(False or  False)
print(False or True)
# Out:
# True
# True
# False
# True

# %%
#logical operator
print(not False)                    #using not
print(not True)
# Out:
# True
# False

# %%
#WAP to compare  two value using and logical operator
a=5
b=6
print(a>b and b<a)               #using and
# Out:
# False

# %%
# WAP  to compare two value using or logical operator
a=5
b=6
print(a>b or b>a)               #using or
print(a>b or b>a)
print(a<b or b>a)
# Out:
# True
# True
# True

# %% [markdown]
# **input**

# %% [markdown]
# 4.Write the program by taking the input from user in python

# %%
#WAP by taking input
n=2
m="5"
sum = n + int(m)
print(sum)
# Out:
# 7

# %%
#WAP bt taken input from the user
name = input("Enter your name: ")            #input from user(name)
print(name)                                  #print name
age = int(input("enter your age: "))         #input from user(age)
print(age)                                   #print age
# Out:
# Enter your name: umang
# umang
# enter your age: 23
# 23

# %%
#WAP to find the area of square by taken inpur from the user
side = int(input("Enter the side:"))         #input from user
area = side*side                             #formula
print(area)                                  #print area
# Out:
# Enter the side:4
# 16
